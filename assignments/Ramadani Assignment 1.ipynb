# %%
import numpy as np 
import pandas as pd 

data = pd.read_csv("/Users/joanner/Downloads/NYPD_Criminal_Court_Summons__Historic_.csv")
data
# Out:
# /Users/joanner/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          SUMMONS_KEY SUMMONS_DATE  \
# 0          173135642   12/31/2017
# 1          173138632   12/31/2017
# 2          173193579   12/31/2017
# 3          173135647   12/31/2017
# 4          173135644   12/31/2017
# ...              ...          ...
# 5262302    191821367   01/01/2019
# 5262303    191883272   01/01/2019
# 5262304    191706620   01/01/2019
# 5262305    191707008   01/01/2019
# 5262306    191709415   01/01/2019
#
#                                        OFFENSE_DESCRIPTION LAW_SECTION_NUMBER  \
# 0                    RIFLE, SHOTGUN, AMMO SALE OR PURCHASE             10-306
# 1                                 MARIJUANA, POSSESSION OF             221.05
# ...

# %%
data.OFFENSE_DESCRIPTION.value_counts()
# Out:
# CONSUMPTION OF ALCOHOL                      1401282
# URINATING IN PUBLIC                          294299
# FAILURE TO COMPLY WITH SIGN                  259313
# BICYCLE ON SIDEWALK                          219443
# DISCON: OBSTRUCT PEDESTRIAN                  210295
#                                              ...
# PRODUCED EXPIRED INSURANCE CARD                   1
# loit ering on school grounds                      1
# LOITERING`                                        1
# TRIP SHEET WITHOUT  REQUIRED OPENING ENT          1
# NO STRAPS ON VEHICLE TOWED                        1
# Name: OFFENSE_DESCRIPTION, Length: 18905, dtype: int64

# %%
data.LAW_DESCRIPTION.value_counts()
# Out:
# Administrative Code               2643044
# Penal Law                         1207170
# Park Regs                          369858
# Health Code                        289167
# VTL                                251602
# NYS Transportation                 202388
# ABC                                 94657
# Traffic Regs                        29008
# Tax Law                             25736
# Other                               22313
# General Business Law                16732
# Transit Regs                        11715
# TLC                                  7128
# Navigation Law                       5386
# ACA                                  5325
# Education Law (NYS)                  2063
# Sanitary Code (NYS)                  1190
# Multiple Dwelling                    1106
# OTHER PARK REGS                       682
# NYS Workers Comp                      441
# DOG: UNLICENSED                       427
# Agriculture & Markets Law             371
# ...

# %%
data.AGE_GROUP.value_counts()
# Out:
# 25-44      2401227
# 18-24      1305114
# 45-64      1103380
# <18         217237
# UNKNOWN      78593
#             ...
# 622              1
# 971              1
# 229              1
# 367              1
# 512              1
# Name: AGE_GROUP, Length: 222, dtype: int64

# %%
data.BORO.value_counts()
# Out:
# BROOKLYN         1392015
# MANHATTAN        1221521
# BRONX            1028106
# QUEENS            866987
# STATEN ISLAND     144851
# NEW YORK           44218
# Name: BORO, dtype: int64

# %%
data.PRECINCT_OF_OCCUR.value_counts()
# Out:
# 40     187687
# 75     186420
# 73     144895
# 79     143765
# 115    142942
#         ...
# 121     16965
# 174       183
# 428         1
# 140         1
# 868         1
# Name: PRECINCT_OF_OCCUR, Length: 81, dtype: int64
